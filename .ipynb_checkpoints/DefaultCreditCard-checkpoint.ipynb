# %%
import pandas as pd
from sqlalchemy import create_engine
reader = pd.read_csv("Resources/Default.csv")
reader
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26     -1      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43     -1     -1
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1     -1
# 30000      30000      50000    1          2         1   46      0      0
#
#           X8     X9  ...        X15        X16        X17       X18       X19  \
# ...

# %%
reader = reader[['X1', 'X2', 'X3', 'X5']].copy()
reader.head(20)
# Out:
#            X1   X2         X3   X5
# 0   LIMIT_BAL  SEX  EDUCATION  AGE
# 1       20000    2          2   24
# 2      120000    2          2   26
# 3       90000    2          2   34
# 4       50000    2          2   37
# 5       50000    1          2   57
# 6       50000    1          1   37
# 7      500000    1          1   29
# 8      100000    2          2   23
# 9      140000    2          3   28
# 10      20000    1          3   35
# 11     200000    2          3   34
# 12     260000    2          1   51
# 13     630000    2          2   41
# 14      70000    1          2   30
# 15     250000    1          1   29
# 16      50000    2          3   23
# 17      20000    1          1   24
# 18     320000    1          1   49
# 19     360000    2          1   49

# %%
reader = reader.rename(columns = {"X1" : "LIMIT_BAL", "X2" : "SEX", "X3" : "EDUCATION", "X5" : "AGE"})

# %%
reader.drop(0)
# Out:
#       LIMIT_BAL SEX EDUCATION AGE
# 1         20000   2         2  24
# 2        120000   2         2  26
# 3         90000   2         2  34
# 4         50000   2         2  37
# 5         50000   1         2  57
# ...         ...  ..       ...  ..
# 29996    220000   1         3  39
# 29997    150000   1         3  43
# 29998     30000   1         2  37
# 29999     80000   1         3  41
# 30000     50000   1         2  46
#
# [30000 rows x 4 columns]

# %%
# !pip install psycopg2-binary

# %%
rds_connection_string = "postgres:postgres@localhost:5432/CreditCardAnalysis"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['balance_limit']

# %%
reader.to_sql(name='balance_limit', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('SELECT * FROM balance_limit', con=engine).head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  AGE
# 0  LIMIT_BAL  SEX  EDUCATION  AGE
# 1      20000    2          2   24
# 2     120000    2          2   26
# 3      90000    2          2   34
# 4      50000    2          2   37
